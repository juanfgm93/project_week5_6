# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
### Loading data

df_final_demo = pd.read_csv("df_final_demo.txt")
df_final_web_1 = pd.read_csv("df_final_web_data_pt_1.txt")
df_final_web_2 = pd.read_csv("df_final_web_data_pt_2.txt")
df_final_clients = pd.read_csv("df_final_experiment_clients.txt")

# %%
### Cleaning data

df_final_demo = df_final_demo.dropna()
df_final_web_1 = df_final_web_1.dropna()
df_final_web_2 = df_final_web_2.dropna()
df_final_clients = df_final_clients.dropna()

df_final_demo = df_final_demo.drop_duplicates()
df_final_web_1 = df_final_web_1.drop_duplicates()
df_final_web_2 = df_final_web_2.drop_duplicates()
df_final_clients = df_final_clients.drop_duplicates()

# %%
### Joining df_webs 1 and 2

df_web_all = pd.concat([df_final_web_1,df_final_web_2], axis = 0)

# %%
df_web_all.duplicated().sum()
# Out:
# 0

# %%
df_web_all
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# 1            step_2  2017-04-17 15:26:51
# 2            step_3  2017-04-17 15:19:22
# 3            step_2  2017-04-17 15:19:13
# 4            step_3  2017-04-17 15:18:04
# ...             ...                  ...
# 412259        start  2017-05-24 18:46:10
# 412260        start  2017-05-24 18:45:29
# 412261       step_1  2017-05-24 18:44:51
# 412262        start  2017-05-24 18:44:34
# 412263        start  2017-06-03 12:17:09
#
# [744641 rows x 5 columns]

# %%
df_final_demo
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth
# 0        45105.30           6.0            9.0
# 1       110860.30           6.0            9.0
# 2        52467.79           6.0            9.0
# 3        67454.65           3.0            6.0
# 4       103671.75           0.0            3.0
# ...           ...           ...            ...
# 70604  1411062.68           5.0            5.0
# 70605   101867.07           6.0            6.0
# 70606    40745.00           3.0            3.0
# 70607   475114.69           4.0            4.0
# 70608   157498.73           7.0            7.0
#
# [70594 rows x 9 columns]

# %%
df_final_clients
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 50495     393005   Control
# 50496    2908510   Control
# 50497    7230446      Test
# 50498    5230357      Test
# 50499    6334360      Test
#
# [50500 rows x 2 columns]

# %%
df_web_all_2 = pd.merge(df_web_all, df_final_clients[['client_id', 'Variation']], on='client_id', how='left')
df_web_all_2.isna().sum()
# Out:
# client_id            0
# visitor_id           0
# visit_id             0
# process_step         0
# date_time            0
# Variation       427406
# dtype: int64

# %%
df_web_all_2 = df_web_all_2.dropna(subset=['Variation'])
df_web_all_2.isna().sum()
# Out:
# client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# date_time       0
# Variation       0
# dtype: int64

# %%
### NUMBER OF CLIENTS INVOLVED IN THE PROCESS

# Define the custom order for process steps
custom_order = ['start', 'step1', 'step2', 'step3', 'confirm']

# Assuming merged_df is your dataframe containing client_id, process_step, and Variation columns

# Count the number of clients for each process step and variation
counts_df = df_web_all_2.groupby(['process_step', 'Variation']).size().reset_index(name='count')

# Create a line plot with custom order
plt.figure(figsize=(10, 6))
sns.lineplot(data=counts_df, x='process_step', y='count', hue='Variation', marker='o', sort=False)
plt.title('Count of Clients by Process Step and Variation')
plt.xlabel('Process Step')
plt.ylabel('Count of Clients')
plt.legend(title='Variation')
plt.xticks(range(len(custom_order)), custom_order, rotation=45)
plt.tight_layout()
plt.show()

# %%
### PRIMARY CLIENTS
quantile_50 = df_final_demo['bal'].quantile(0.5)
primary_clients = df_final_demo[df_final_demo['bal'] >= quantile_50]
filtered_df_nonprimary = df_final_demo[(df_final_demo['bal'] < df_final_demo['bal'].median())]

# %%
primary_clients
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 1        2304905             7.0              94.0      58.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# 7         388801            30.0             361.0      57.5     M        5.0
# 8         285619            30.0             369.0      67.5     M        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70599    4851159             6.0              79.0      60.0     U        2.0
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth
# 1       110860.30           6.0            9.0
# 3        67454.65           3.0            6.0
# 4       103671.75           0.0            3.0
# 7       522498.72           1.0            4.0
# 8       299388.72           3.0            6.0
# ...           ...           ...            ...
# 70599    74501.76           4.0            4.0
# 70604  1411062.68           5.0            5.0
# 70605   101867.07           6.0            6.0
# 70607   475114.69           4.0            4.0
# 70608   157498.73           7.0            7.0
#
# [35297 rows x 9 columns]

# %%
bal_mean = primary_clients['bal'].mean()
bal_median = primary_clients['bal'].median()
bal_std  = primary_clients['bal'].std()
bal_range = primary_clients['bal'].max() - primary_clients['bal'].min()

bal_mean, bal_median, bal_std, bal_range
# Out:
# (256205.60015950364,
#  137547.33000000002,
#  397508.66036989103,
#  16256703.870000001)

# %% [markdown]
# # Why everything > than median for your pimary customers?

# %%
primary_clients['bal'].sum()
#9,043,289,068.83
# Out:
# 9043289068.83

# %%
filtered_df_nonprimary['bal'].sum()
#1,365,565,143.70
# Out:
# 1365565143.7000003

# %% [markdown]
# # AGE

# %%
sns.histplot(primary_clients['clnt_age'], kde=True, bins=30, color="salmon")
# Out:
# <Axes: xlabel='clnt_age', ylabel='Count'>

# %%
sns.histplot(filtered_df_nonprimary['clnt_age'], kde=True, bins=30, color="salmon")
# Out:
# <Axes: xlabel='clnt_age', ylabel='Count'>

# %%
sns.histplot(df_final_demo['clnt_age'], kde=True, bins=30, color="salmon")
# Out:
# <Axes: xlabel='clnt_age', ylabel='Count'>

# %% [markdown]
# # Are the primary clients new or long-standing?

# %%
sns.histplot(primary_clients['clnt_tenure_yr'], kde=True, bins=30, color="salmon")
# Out:
# <Axes: xlabel='clnt_tenure_yr', ylabel='Count'>

# %%
sns.histplot(filtered_df_nonprimary['clnt_tenure_yr'], kde=True, bins=30, color="salmon")
# Out:
# <Axes: xlabel='clnt_tenure_yr', ylabel='Count'>

# %%
sns.histplot(df_final_demo['clnt_tenure_yr'], kde=True, bins=30, color="salmon")
# Out:
# <Axes: xlabel='clnt_tenure_yr', ylabel='Count'>

# %% [markdown]
# # Time Spent on Each Step: Average duration users spend on each step.

# %%
# Convert the 'Login_time' column to datetime type
df_web_all_2['date_time'] = pd.to_datetime(df_web_all_2['date_time'])

# Sort the dataframe by 'ID_client' and 'Login_time'
df_web_all_2 = df_web_all_2.sort_values(by=['visit_id', 'date_time'])

# Calculate the time spent on each step for each client
df_web_all_2['Time_spent'] = df_web_all_2.groupby('visit_id')['date_time'].diff()

# %%
# Filter out rows with NaT values in the 'Time_spent' column
filtered_df = df_web_all_2.dropna(subset=['Time_spent'])

# Convert timedelta to seconds
filtered_df['Time_spent_seconds'] = filtered_df['Time_spent'].dt.total_seconds()
# Out:
# C:\Users\juan_\AppData\Local\Temp\ipykernel_14024\627628057.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Time_spent_seconds'] = filtered_df['Time_spent'].dt.total_seconds()

# %%
Q1 = filtered_df['Time_spent'].quantile(0.25)
Q3 = filtered_df['Time_spent'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for the outliers
lower_bound = Q1 - 10 * IQR
upper_bound = Q3 + 10 * IQR

# Identify and remove the outliers
filtered_df = filtered_df[filtered_df['Time_spent'] < upper_bound]

# %%
filtered_df
# Out:
#         client_id             visitor_id                      visit_id  \
# 107970    3561384   451664975_1722933822  100012776_37918976071_457913
# 239140    7338123  612065484_94198474375   100019538_17884295066_43909
# 239139    7338123  612065484_94198474375   100019538_17884295066_43909
# 239138    7338123  612065484_94198474375   100019538_17884295066_43909
# 239137    7338123  612065484_94198474375   100019538_17884295066_43909
# ...           ...                    ...                           ...
# 91950     4064969  110735946_42614968419  999985675_64610694964_443659
# 96653     6627522  730634087_44272418812  999988789_76411676596_272843
# 96652     6627522  730634087_44272418812  999988789_76411676596_272843
# 96651     6627522  730634087_44272418812  999988789_76411676596_272843
# 96650     6627522  730634087_44272418812  999988789_76411676596_272843
#
#        process_step           date_time Variation      Time_spent  \
# 107970      confirm 2017-04-26 13:23:09      Test 0 days 00:00:52
# 239140       step_1 2017-04-09 16:21:12      Test 0 days 00:00:16
# 239139       step_2 2017-04-09 16:21:21      Test 0 days 00:00:09
# 239138       step_1 2017-04-09 16:21:35      Test 0 days 00:00:14
# 239137       step_1 2017-04-09 16:21:41      Test 0 days 00:00:06
# ...             ...                 ...       ...             ...
# 91950        step_3 2017-04-20 09:48:45   Control 0 days 00:01:41
# 96653        step_1 2017-04-21 23:49:22      Test 0 days 00:00:11
# 96652        step_2 2017-04-21 23:50:16      Test 0 days 00:00:54
# 96651        step_1 2017-04-21 23:51:00      Test 0 days 00:00:44
# 96650         start 2017-04-21 23:51:09      Test 0 days 00:00:09
#
#         Time_spent_seconds
# 107970                52.0
# 239140                16.0
# 239139                 9.0
# 239138                14.0
# 239137                 6.0
# ...                    ...
# 91950                101.0
# 96653                 11.0
# 96652                 54.0
# 96651                 44.0
# 96650                  9.0
#
# [244667 rows x 8 columns]

# %% [markdown]
# * KEEP ONLY THOSE VISIT_IDs THAT HAVE THE FOUR STEPS ONE AFTER ANOTHER

# %%
# Step 1: Group the DataFrame by 'visit_id'
grouped = filtered_df.groupby('visit_id')

# Step 2: Check if each group contains all four steps
def has_required_steps(group):
    return set(group['process_step']) == {'step_1', 'step_2', 'step_3', 'confirm'}

# Step 3: Filter groups to keep only those that have all four required steps
filtered_groups = grouped.filter(has_required_steps)

# Step 4: Extract corresponding rows from the original DataFrame
filtered_clients = filtered_df[filtered_df['visit_id'].isin(filtered_groups['visit_id'])]

# Display the resulting DataFrame
filtered_clients
# Out:
#         client_id             visitor_id                      visit_id  \
# 350400    2478628  754122351_18568832435  100022086_87870757897_149620
# 350399    2478628  754122351_18568832435  100022086_87870757897_149620
# 350398    2478628  754122351_18568832435  100022086_87870757897_149620
# 350397    2478628  754122351_18568832435  100022086_87870757897_149620
# 241108    3479519  194422203_56127484794   10006594_66157970412_679648
# ...           ...                    ...                           ...
# 211739    4449968  842902495_57580498240  999976049_95772503197_182554
# 81208      829911  648229874_89449279372  999984454_18731538378_781808
# 81207      829911  648229874_89449279372  999984454_18731538378_781808
# 81206      829911  648229874_89449279372  999984454_18731538378_781808
# 81205      829911  648229874_89449279372  999984454_18731538378_781808
#
#        process_step           date_time Variation      Time_spent  \
# 350400       step_1 2017-05-23 20:44:23      Test 0 days 00:00:22
# 350399       step_2 2017-05-23 20:45:08      Test 0 days 00:00:45
# 350398       step_3 2017-05-23 20:46:01      Test 0 days 00:00:53
# 350397      confirm 2017-05-23 20:47:01      Test 0 days 00:01:00
# 241108       step_1 2017-04-13 11:50:28   Control 0 days 00:00:10
# ...             ...                 ...       ...             ...
# 211739      confirm 2017-04-04 13:02:18      Test 0 days 00:02:43
# 81208        step_1 2017-03-29 11:18:51      Test 0 days 00:00:18
# 81207        step_2 2017-03-29 11:19:32      Test 0 days 00:00:41
# 81206        step_3 2017-03-29 11:20:23      Test 0 days 00:00:51
# 81205       confirm 2017-03-29 11:21:07      Test 0 days 00:00:44
#
#         Time_spent_seconds
# 350400                22.0
# 350399                45.0
# 350398                53.0
# 350397                60.0
# 241108                10.0
# ...                    ...
# 211739               163.0
# 81208                 18.0
# 81207                 41.0
# 81206                 51.0
# 81205                 44.0
#
# [111865 rows x 8 columns]

# %% [markdown]
# * REMOVE REPETED STEPS FOR SAME CLIENT_ID

# %%
# Sort the DataFrame by 'date_time' within each group
filtered_df_sorted = filtered_df.sort_values(by='date_time')

# Step 1: Group the DataFrame by 'visit_id'
grouped = filtered_df_sorted.groupby('visit_id')

# Step 2: Define a function to filter each group
def filter_group(group):
    # Keep only the earliest occurrence of each step
    filtered_group = group.drop_duplicates(subset='process_step')
    # Check if the group contains all four required steps
    if set(filtered_group['process_step']) == {'step_1', 'step_2', 'step_3', 'confirm'}:
        return filtered_group
    else:
        return pd.DataFrame()  # Return an empty DataFrame if the group does not meet the criteria

# Step 3: Apply the filtering function to each group and concatenate the results
filtered_clients = grouped.apply(filter_group).reset_index(drop=True)

# Display the resulting DataFrame
filtered_clients
# Out:
#         client_id             visitor_id                      visit_id  \
# 0       2478628.0  754122351_18568832435  100022086_87870757897_149620
# 1       2478628.0  754122351_18568832435  100022086_87870757897_149620
# 2       2478628.0  754122351_18568832435  100022086_87870757897_149620
# 3       2478628.0  754122351_18568832435  100022086_87870757897_149620
# 4       3479519.0  194422203_56127484794   10006594_66157970412_679648
# ...           ...                    ...                           ...
# 100111  4449968.0  842902495_57580498240  999976049_95772503197_182554
# 100112   829911.0  648229874_89449279372  999984454_18731538378_781808
# 100113   829911.0  648229874_89449279372  999984454_18731538378_781808
# 100114   829911.0  648229874_89449279372  999984454_18731538378_781808
# 100115   829911.0  648229874_89449279372  999984454_18731538378_781808
#
#        process_step           date_time Variation      Time_spent  \
# 0            step_1 2017-05-23 20:44:23      Test 0 days 00:00:22
# 1            step_2 2017-05-23 20:45:08      Test 0 days 00:00:45
# 2            step_3 2017-05-23 20:46:01      Test 0 days 00:00:53
# 3           confirm 2017-05-23 20:47:01      Test 0 days 00:01:00
# 4            step_1 2017-04-13 11:50:28   Control 0 days 00:00:10
# ...             ...                 ...       ...             ...
# 100111      confirm 2017-04-04 13:02:18      Test 0 days 00:02:43
# 100112       step_1 2017-03-29 11:18:51      Test 0 days 00:00:18
# 100113       step_2 2017-03-29 11:19:32      Test 0 days 00:00:41
# 100114       step_3 2017-03-29 11:20:23      Test 0 days 00:00:51
# 100115      confirm 2017-03-29 11:21:07      Test 0 days 00:00:44
#
#         Time_spent_seconds
# 0                     22.0
# 1                     45.0
# 2                     53.0
# 3                     60.0
# 4                     10.0
# ...                    ...
# 100111               163.0
# 100112                18.0
# 100113                41.0
# 100114                51.0
# 100115                44.0
#
# [100116 rows x 8 columns]

# %%
sns.boxplot(data=filtered_clients, x='process_step', y='Time_spent_seconds')
# Out:
# <Axes: xlabel='process_step', ylabel='Time_spent_seconds'>

# %%
sns.boxplot(data=filtered_clients['Time_spent_seconds'])
# Out:
# <Axes: >

# %%
filtered_clients['process_step'].unique()
# Out:
# array(['step_1', 'step_2', 'step_3', 'confirm'], dtype=object)

# %%
# Convert 'Time_spent' column to numeric data type (assuming it contains timedelta values)
#filtered_clients['Time_spent_seconds'] = pd.to_numeric(filtered_clients['Time_spent_seconds'].dt.total_seconds())

# Plotting the bar chart with variations on the x-axis and average time spent on the y-axis for each process step
plt.figure(figsize=(12, 8))
sns.barplot(data=filtered_clients, x='process_step', y='Time_spent_seconds', hue='Variation', palette="Set2")
plt.title('Average Time Spent on Each Process Step: Test vs Control')
plt.xlabel('Process Step')
plt.ylabel('Average Time Spent (seconds)')
plt.legend(title='Variation')
plt.show()

# %% [markdown]
# # Completion Rate: proportion of users who reach the final ‘confirm’ step.

# %%
df_control = filtered_clients[filtered_clients['Variation'] == 'Control']
df_test = filtered_clients[filtered_clients['Variation'] == 'Test']

# %%
df_control['date_time'] = pd.to_datetime(df_control['date_time'])
# Step 2: Calculate time spent for each step
df_control['Time_spent'] = df_control.groupby('visit_id')['date_time'].diff()
# Out:
# C:\Users\juan_\AppData\Local\Temp\ipykernel_14024\3795534565.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_control['date_time'] = pd.to_datetime(df_control['date_time'])
# C:\Users\juan_\AppData\Local\Temp\ipykernel_14024\3795534565.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_control['Time_spent'] = df_control.groupby('visit_id')['date_time'].diff()

# %%
df_test['date_time'] = pd.to_datetime(df_test['date_time'])
# Step 2: Calculate time spent for each step
df_test['Time_spent'] = df_test.groupby('visit_id')['date_time'].diff()
# Out:
# C:\Users\juan_\AppData\Local\Temp\ipykernel_14024\1342730896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['date_time'] = pd.to_datetime(df_test['date_time'])
# C:\Users\juan_\AppData\Local\Temp\ipykernel_14024\1342730896.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['Time_spent'] = df_test.groupby('visit_id')['date_time'].diff()

# %%
df_unique_control = df_control.drop_duplicates(subset=['client_id', 'Variation'])[['client_id', 'Variation']]
df_unique_test = df_test.drop_duplicates(subset=['client_id', 'Variation'])[['client_id', 'Variation']]

# %%
df_final_clients_2 = df_final_clients

# %%
merged_control = pd.merge(df_final_clients_2, df_unique_control, on='client_id', how='left')

merged_test = pd.merge(df_final_clients_2, df_unique_test, on='client_id', how='left')

# Create a new column 'completion' in df_final_clients_2
df_final_clients_2['completion'] = 0

# Update completion column based on presence in df_unique_control and df_unique_test
df_final_clients_2.loc[merged_control['Variation_y'].notnull(), 'completion'] = 1
df_final_clients_2.loc[merged_test['Variation_y'].notnull(), 'completion'] = 1

# Display the updated df_final_clients_2
df_final_clients_2
# Out:
#        client_id Variation  completion
# 0        9988021      Test           0
# 1        8320017      Test           1
# 2        4033851   Control           1
# 3        1982004      Test           1
# 4        9294070   Control           0
# ...          ...       ...         ...
# 50495     393005   Control           0
# 50496    2908510   Control           0
# 50497    7230446      Test           0
# 50498    5230357      Test           0
# 50499    6334360      Test           1
#
# [50500 rows x 3 columns]

# %%
df_final_clients_2.groupby('Variation')['completion'].value_counts()
# Out:
# Variation  completion
# Control    1             11958
#            0             11574
# Test       0             13932
#            1             13036
# Name: count, dtype: int64

# %% [markdown]
# # Error Rates

# %% [markdown]
# ** Here, we don't use filtered_df, but instead df_well_all_2, since filtered_df has no errors

# %%
# Assuming df_web_all2 is your DataFrame
# Step 1: Sort the DataFrame
df_web_all_2.sort_values(by=['client_id', 'visitor_id', 'date_time'], inplace=True)

# Step 2: Identify instances of going back to a previous step
df_web_all_2['previous_step'] = df_web_all_2.groupby(['client_id', 'visitor_id'])['process_step'].shift(1)

# Count instances where the current step is a step back
error_counts = df_web_all_2[df_web_all_2['process_step'] < df_web_all_2['previous_step']].groupby(['client_id', 'visitor_id']).size().reset_index(name='error_count')

# Step 3: Calculate error rates
total_visits = df_web_all_2.groupby(['client_id', 'visitor_id']).size().reset_index(name='total_visits')

# Merge error counts with total visits
error_rates_df = pd.merge(total_visits, error_counts, on=['client_id', 'visitor_id'], how='left').fillna(0)

# Calculate error rates
error_rates_df['error_rate'] = error_rates_df['error_count'] / error_rates_df['total_visits']

# Display the DataFrame with error rates
display(error_rates_df.head())
# Out:
#    client_id             visitor_id  total_visits  error_count  error_rate
# 0        555  402506806_56087378777             5          1.0    0.200000
# 1        647   66758770_53988066587             5          1.0    0.200000
# 2        934  810392784_45004760546             4          0.0    0.000000
# 3       1028   42237450_62128060588             9          2.0    0.222222
# 4       1104  194240915_18158000533             2          0.0    0.000000

# %%
error_rates_df_1 = pd.merge(error_rates_df, df_final_clients[['client_id', 'Variation']], on='client_id', how='left')

# %%
error_rates_df_1
# Out:
#        client_id             visitor_id  total_visits  error_count  \
# 0            555  402506806_56087378777             5          1.0
# 1            647   66758770_53988066587             5          1.0
# 2            934  810392784_45004760546             4          0.0
# 3           1028   42237450_62128060588             9          2.0
# 4           1104  194240915_18158000533             2          0.0
# ...          ...                    ...           ...          ...
# 56368    9999626   52633065_71189986073             2          0.0
# 56369    9999729  604429154_69247391147             2          0.0
# 56370    9999729  834634258_21862004160             5          1.0
# 56371    9999729  843385170_36953471821             4          1.0
# 56372    9999832  145538019_54444341400             2          0.0
#
#        error_rate Variation
# 0        0.200000      Test
# 1        0.200000      Test
# 2        0.000000      Test
# 3        0.222222   Control
# 4        0.000000   Control
# ...           ...       ...
# 56368    0.000000      Test
# 56369    0.000000      Test
# 56370    0.200000      Test
# 56371    0.250000      Test
# 56372    0.000000      Test
#
# [56373 rows x 6 columns]

# %%
# Group data by 'Variation' and calculate the sum of 'error_count' for each group
grouped_data = error_rates_df_1.groupby('Variation')['error_count'].sum()

# Create a bar plot
plt.figure(figsize=(8, 6))
grouped_data.plot(kind='bar', color=['blue', 'orange'])
plt.title('Comparison of Errors in Test vs Control')
plt.xlabel('Variation')
plt.ylabel('Total Errors')
plt.xticks(rotation=0)
plt.show()

# %%
# creating one df with steps
merged_error_rates_df_2 = error_rates_df.merge(df_web_all_2, on='client_id', how='inner')
merged_error_rates_df_2 = merged_error_rates_df_2.drop(['visitor_id_x','visitor_id_y','visit_id','previous_step', 'Time_spent'], axis=1)

# %%
plt.figure(figsize=(14, 7))
sns.lineplot(data=merged_error_rates_df_2, x='process_step', y='error_count',hue='Variation', ci=None)
plt.title('Error per Process Step')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
# Out:
# C:\Users\juan_\AppData\Local\Temp\ipykernel_14024\752076414.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=merged_error_rates_df_2, x='process_step', y='error_count',hue='Variation', ci=None)

# %% [markdown]
# # TABLEAU

# %%
### DATA FRAMES - PRIMARY VS NON PRIMARY - FOR AGE AND YEARS IN COMPANY
primary_clients.to_csv('primary_clients.csv', index=False)
filtered_df_nonprimary.to_csv('filtered_df_nonprimary.csv', index=False)
### DATA FRAME FOR COMPLETION RATES
df_final_clients_2.to_csv('df_final_clients_2.csv',index=False)

### DATA FRAME FOR ERROR RATES - WITHOUT SPECIFYING STEPS
error_rates_df_1.to_csv('error_rates_df_1.csv',index=False)

### DATA FRAME FOR ERROR RATES - SPECIFYING STEPS
merged_error_rates_df_2.to_csv('merged_error_rates_df_2.csv',index=False)

### DATA FRAME FOR TIME SPENT
filtered_clients.to_csv('filtered_clients.csv',index=False)

# %% [markdown]
# # HIPOTHESIS TESTING

# %%
# Hypothesis to test if completion rate is different in Test and Control groups.
